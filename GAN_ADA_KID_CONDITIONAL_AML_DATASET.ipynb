# %% [markdown]
# Code adapted from [this github code](https://github.com/keras-team/keras-io/blob/master/examples/generative/gan_ada.py) for unconditional DCGANs and [this one](https://colab.research.google.com/github/keras-team/keras-io/blob/master/examples/generative/ipynb/conditional_gan.ipynb#scrollTo=zFcFxIfJev2H) for conditional DCGANs

# %% [markdown]
# # My code

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Global variables

# %%
DELETE_RUNTIME_AT_END = False #@param {type:"boolean"}

# %%
LAST_EPOCH_FILE_NAME = "last_epoch.pkl"
RB5000_DATASET_PATH = "/content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoBalanceado5000"
R_DATASET_PATH = "/content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducido"
RS_DATASET_PATH = "/content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit"
DATASET_PATH = RS_DATASET_PATH

GAN_MODEL_DATA_PATH = "/content/drive/MyDrive/MASTER/TFM/Train Data/GAN Models"
ADA_TRAIN_DATA_PATH = "/content/drive/MyDrive/MASTER/TFM/Train Data/GAN_ADA_KID_CONDITIONAL"
ADA_MODEL_PATH = "/content/drive/MyDrive/MASTER/TFM/Train Data/GAN_ADA_KID_CONDITIONAL/Model"
N_SAMPLES_PER_LABEL = {}
PARTITION_COUNT = {"train": 4500, "validation": 495, "test": 5}
# OOM with 160 of shape side and a T4 GPU, the GPU RAM consumed is 14.2/15 GB but it gets the error
SHAPE_SIDE = 144
if(not (SHAPE_SIDE/8).is_integer()):
  raise Exception("SHAPE SIDE INVALID")
SHAPE = (SHAPE_SIDE,SHAPE_SIDE,3)

# %%
def DISCRIMINATOR_MODEL_NAME(epoch):
  return f"discriminator_model_{epoch}.h5"
def GENERATOR_MODEL_NAME(epoch):
  return f"generator_model_{epoch}.h5"
def GAN_MODEL_NAME(epoch):
  return f"gan_model_{epoch}.h5"

# %%
LABELS = ["BAS","EBO","EOS","KSC","LYA","LYT","MMZ","MOB","MON","MYB","MYO","NGB","NGS","PMB","PMO"]
num_classes= len(LABELS)
CODE_TO_LABEL = {
    0:"BAS",
    1:"EBO",
    2:"EOS",
    3:"KSC",
    4:"LYA",
    5:"LYT",
    6:"MMZ",
    7:"MOB",
    8:"MON",
    9:"MYB",
    10:"MYO",
    11:"NGB",
    12:"NGS",
    13:"PMB",
    14:"PMO",
}
LABEL_TO_CODE = {
    "BAS":0,
    "EBO":1,
    "EOS":2,
    "KSC":3,
    "LYA":4,
    "LYT":5,
    "MMZ":6,
    "MOB":7,
    "MON":8,
    "MYB":9,
    "MYO":10,
    "NGB":11,
    "NGS":12,
    "PMB":13,
    "PMO":14,
}
LABELS_ABREVIATIONS = {
    "BAS": "Basophil",
    "EBO": "Erythroblast",
    "EOS": "Eosinophil",
    "KSC": "Smudge cell",
    "LYA": "Lymphocyte (atypical)",
    "LYT": "Lymphocyte (typical)",
    "MMZ": "Metamyelocyte",
    "MOB": "Monoblast",
    "MON": "Monocyte",
    "MYB": "Myelocyte",
    "MYO": "Myeloblast",
    "NGB": "Neutrophil (band)",
    "NGS": "Neutrophil (segmented)",
    "PMB": "Promyelocyte (bilobled)",
    "PMO": "Promyelocyte",
}

# %%
# THIS CODE WAS MADE TO PASS FROM ReducedDataset to ReducedDatasetSplit, beacuse the dataset was not divided into the three partitions

# def split_number(total, percentages=[80,10,10]):
#     counts = [int(total * p / 100) for p in percentages]
#     remainder = total - sum(counts)
#     counts[0] += remainder
#     return counts

# def split_list(images, split_counts):
#     split_lists = []
#     start_index = 0
#     for count in split_counts:
#         end_index = start_index + count
#         split_lists.append(images[start_index:end_index])
#         start_index = end_index
#     return split_lists

# partitions = ['train','validation','test']

# for label_text in LABELS:
#   label_code = LABEL_TO_CODE[label_text]
#   label_path = os.path.join(R_DATASET_PATH,label_text)

#   label_count = len(os.listdir(label_path))
#   print(f"{label_text}: {label_count}")
#   split_counts = split_number(label_count)

#   label_images = []
#   for image_name in os.listdir(label_path):
#     img_path = os.path.join(label_path, image_name)
#     label_images.append(np.array(PIL.Image.open(img_path))[:,:,:3])

#   train_split, val_split, test_split = split_list(label_images, split_counts)
#   print(len(train_split))

#   for idx, img  in enumerate(train_split):
#     file_name = f"TRAIN_{idx+1}.bmp"
#     file_path = os.path.join(RS_DATASET_PATH,'train',label_text,file_name)
#     image = PIL.Image.fromarray(img)
#     image.save(file_path)

#   for idx, img in enumerate(val_split):
#     file_name = f"VAL_{idx+1}.bmp"
#     file_path = os.path.join(RS_DATASET_PATH,'validation',label_text,file_name)
#     image = PIL.Image.fromarray(img)
#     image.save(file_path)

#   for idx, img in enumerate(test_split):
#     file_name = f"TEST_{idx+1}.bmp"
#     file_path = os.path.join(RS_DATASET_PATH,'test',label_text,file_name)
#     image = PIL.Image.fromarray(img)
#     image.save(file_path)

# %% [markdown]
# ### Imports

# %%
import numpy as np
import keras
import os
import PIL
import tensorflow as tf
from matplotlib import pyplot as plt
import cv2
import random
import math
from google.colab import runtime

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

from keras.utils.np_utils import to_categorical

import plotly.graph_objects as go
from plotly.subplots import make_subplots

from google.colab import data_table
data_table.enable_dataframe_formatter()
import pandas as pd

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

from os import path
import pickle

from collections import Counter

# example of semi-supervised gan for mnist
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy import asarray
from numpy.random import randn
from numpy.random import randint
from keras.datasets.mnist import load_data
from keras.optimizers import Adam
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from keras.layers import Lambda
from keras.layers import Activation
from matplotlib import pyplot
from keras import backend

# %% [markdown]
# ### Read images

# %%
def split_sample_to_partition(image, label, partition):
  if partition == 'train':
    train_images.append(image)
    train_labels.append(label)
  elif partition == 'validation':
    val_images.append(image)
    val_labels.append(label)
  elif partition == 'test':
    test_images.append(image)
    test_labels.append(label)

# %%
def check_partitions_count(partitions):
  for label in LABELS:
    label_code = LABEL_TO_CODE[label]
    checks = []
    print(f"Checking sample count for {label}:")
    for partition in partitions:
      labels_path = os.path.join(DATASET_PATH,partition)
      label_text = CODE_TO_LABEL[label_code]
      label_path = os.path.join(DATASET_PATH,partition, label_text)
      label_images = os.listdir(label_path)
      count = len(label_images)
      N_SAMPLES_PER_LABEL[label_text] = count
      print(f"Expected sample count: {PARTITION_COUNT[partition]}\t observed: {count}")
      if (PARTITION_COUNT[partition] != count): checks.append(False)
      else: checks.append(True)
    if False in checks:
      raise Exception("Unexpected number of samples")
    else:
      print("OK. expected number of samples")

# %%
train_images = []
train_labels = []
val_images = []
val_labels = []
test_images = []
test_labels = []

partitions = os.listdir(DATASET_PATH)
# check_partitions_count(partitions)

# %%
for label_text in LABELS:
  label_code = LABEL_TO_CODE[label_text]
  for partition in partitions:
    labels_path = os.path.join(DATASET_PATH,partition)
    labels_texts = os.listdir(labels_path)
    n_labels = len(labels_texts)
    label_path = os.path.join(DATASET_PATH,partition, label_text)
    label_images = os.listdir(label_path)
    print(label_path)
    print(len(label_images))
    for j,img_text in enumerate(label_images):
      print(f"{partition} {label_text}: {j}. {img_text}")
      img_path = os.path.join(DATASET_PATH,partition,label_text,img_text)
      img = np.array(PIL.Image.open(img_path))[:,:,:3]
      img = cv2.resize(img, (SHAPE_SIDE, SHAPE_SIDE))
      split_sample_to_partition(img, to_categorical(LABEL_TO_CODE[label_text],n_labels), partition)
# Out:
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/train/BAS
# 65
# train BAS: 0. TRAIN_1.bmp
# train BAS: 1. TRAIN_3.bmp
# train BAS: 2. TRAIN_4.bmp
# train BAS: 3. TRAIN_7.bmp
# train BAS: 4. TRAIN_8.bmp
# train BAS: 5. TRAIN_9.bmp
# train BAS: 6. TRAIN_6.bmp
# train BAS: 7. TRAIN_11.bmp
# train BAS: 8. TRAIN_5.bmp
# train BAS: 9. TRAIN_10.bmp
# train BAS: 10. TRAIN_2.bmp
# train BAS: 11. TRAIN_12.bmp
# train BAS: 12. TRAIN_13.bmp
# train BAS: 13. TRAIN_15.bmp
# train BAS: 14. TRAIN_14.bmp
# train BAS: 15. TRAIN_17.bmp
# train BAS: 16. TRAIN_19.bmp
# train BAS: 17. TRAIN_16.bmp
# train BAS: 18. TRAIN_20.bmp
# train BAS: 19. TRAIN_18.bmp
# train BAS: 20. TRAIN_21.bmp
# train BAS: 21. TRAIN_22.bmp
# train BAS: 22. TRAIN_23.bmp
# train BAS: 23. TRAIN_24.bmp
# train BAS: 24. TRAIN_26.bmp
# train BAS: 25. TRAIN_27.bmp
# train BAS: 26. TRAIN_25.bmp
# train BAS: 27. TRAIN_28.bmp
# train BAS: 28. TRAIN_29.bmp
# train BAS: 29. TRAIN_30.bmp
# train BAS: 30. TRAIN_31.bmp
# train BAS: 31. TRAIN_32.bmp
# train BAS: 32. TRAIN_35.bmp
# train BAS: 33. TRAIN_36.bmp
# train BAS: 34. TRAIN_37.bmp
# train BAS: 35. TRAIN_34.bmp
# train BAS: 36. TRAIN_33.bmp
# train BAS: 37. TRAIN_38.bmp
# train BAS: 38. TRAIN_40.bmp
# train BAS: 39. TRAIN_39.bmp
# train BAS: 40. TRAIN_41.bmp
# train BAS: 41. TRAIN_42.bmp
# train BAS: 42. TRAIN_43.bmp
# train BAS: 43. TRAIN_44.bmp
# train BAS: 44. TRAIN_45.bmp
# train BAS: 45. TRAIN_46.bmp
# train BAS: 46. TRAIN_47.bmp
# train BAS: 47. TRAIN_48.bmp
# train BAS: 48. TRAIN_49.bmp
# train BAS: 49. TRAIN_50.bmp
# train BAS: 50. TRAIN_51.bmp
# train BAS: 51. TRAIN_52.bmp
# train BAS: 52. TRAIN_53.bmp
# train BAS: 53. TRAIN_54.bmp
# train BAS: 54. TRAIN_55.bmp
# train BAS: 55. TRAIN_56.bmp
# train BAS: 56. TRAIN_57.bmp
# train BAS: 57. TRAIN_58.bmp
# train BAS: 58. TRAIN_59.bmp
# train BAS: 59. TRAIN_60.bmp
# train BAS: 60. TRAIN_61.bmp
# train BAS: 61. TRAIN_62.bmp
# train BAS: 62. TRAIN_63.bmp
# train BAS: 63. TRAIN_64.bmp
# train BAS: 64. TRAIN_65.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/validation/BAS
# 8
# validation BAS: 0. BAS_0001.tiff
# validation BAS: 1. VAL_1.bmp
# validation BAS: 2. VAL_2.bmp
# validation BAS: 3. VAL_3.bmp
# validation BAS: 4. VAL_4.bmp
# validation BAS: 5. VAL_5.bmp
# validation BAS: 6. VAL_6.bmp
# validation BAS: 7. VAL_7.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/test/BAS
# 8
# test BAS: 0. BAS_0001.tiff
# test BAS: 1. TEST_1.bmp
# test BAS: 2. TEST_2.bmp
# test BAS: 3. TEST_3.bmp
# test BAS: 4. TEST_4.bmp
# test BAS: 5. TEST_5.bmp
# test BAS: 6. TEST_6.bmp
# test BAS: 7. TEST_7.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/train/EBO
# 64
# train EBO: 0. TRAIN_1.bmp
# train EBO: 1. TRAIN_2.bmp
# train EBO: 2. TRAIN_3.bmp
# train EBO: 3. TRAIN_4.bmp
# train EBO: 4. TRAIN_5.bmp
# train EBO: 5. TRAIN_6.bmp
# train EBO: 6. TRAIN_7.bmp
# train EBO: 7. TRAIN_8.bmp
# train EBO: 8. TRAIN_9.bmp
# train EBO: 9. TRAIN_10.bmp
# train EBO: 10. TRAIN_11.bmp
# train EBO: 11. TRAIN_12.bmp
# train EBO: 12. TRAIN_13.bmp
# train EBO: 13. TRAIN_14.bmp
# train EBO: 14. TRAIN_15.bmp
# train EBO: 15. TRAIN_16.bmp
# train EBO: 16. TRAIN_17.bmp
# train EBO: 17. TRAIN_18.bmp
# train EBO: 18. TRAIN_19.bmp
# train EBO: 19. TRAIN_20.bmp
# train EBO: 20. TRAIN_21.bmp
# train EBO: 21. TRAIN_22.bmp
# train EBO: 22. TRAIN_23.bmp
# train EBO: 23. TRAIN_24.bmp
# train EBO: 24. TRAIN_25.bmp
# train EBO: 25. TRAIN_26.bmp
# train EBO: 26. TRAIN_27.bmp
# train EBO: 27. TRAIN_28.bmp
# train EBO: 28. TRAIN_29.bmp
# train EBO: 29. TRAIN_30.bmp
# train EBO: 30. TRAIN_31.bmp
# train EBO: 31. TRAIN_32.bmp
# train EBO: 32. TRAIN_33.bmp
# train EBO: 33. TRAIN_34.bmp
# train EBO: 34. TRAIN_35.bmp
# train EBO: 35. TRAIN_36.bmp
# train EBO: 36. TRAIN_37.bmp
# train EBO: 37. TRAIN_38.bmp
# train EBO: 38. TRAIN_39.bmp
# train EBO: 39. TRAIN_40.bmp
# train EBO: 40. TRAIN_41.bmp
# train EBO: 41. TRAIN_42.bmp
# train EBO: 42. TRAIN_43.bmp
# train EBO: 43. TRAIN_44.bmp
# train EBO: 44. TRAIN_45.bmp
# train EBO: 45. TRAIN_46.bmp
# train EBO: 46. TRAIN_47.bmp
# train EBO: 47. TRAIN_48.bmp
# train EBO: 48. TRAIN_49.bmp
# train EBO: 49. TRAIN_50.bmp
# train EBO: 50. TRAIN_51.bmp
# train EBO: 51. TRAIN_52.bmp
# train EBO: 52. TRAIN_53.bmp
# train EBO: 53. TRAIN_54.bmp
# train EBO: 54. TRAIN_55.bmp
# train EBO: 55. TRAIN_56.bmp
# train EBO: 56. TRAIN_57.bmp
# train EBO: 57. TRAIN_58.bmp
# train EBO: 58. TRAIN_59.bmp
# train EBO: 59. TRAIN_60.bmp
# train EBO: 60. TRAIN_61.bmp
# train EBO: 61. TRAIN_62.bmp
# train EBO: 62. TRAIN_63.bmp
# train EBO: 63. TRAIN_64.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/validation/EBO
# 7
# validation EBO: 0. VAL_1.bmp
# validation EBO: 1. VAL_2.bmp
# validation EBO: 2. VAL_3.bmp
# validation EBO: 3. VAL_4.bmp
# validation EBO: 4. VAL_5.bmp
# validation EBO: 5. VAL_6.bmp
# validation EBO: 6. VAL_7.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/test/EBO
# 7
# test EBO: 0. TEST_1.bmp
# test EBO: 1. TEST_2.bmp
# test EBO: 2. TEST_3.bmp
# test EBO: 3. TEST_4.bmp
# test EBO: 4. TEST_5.bmp
# test EBO: 5. TEST_6.bmp
# test EBO: 6. TEST_7.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/train/EOS
# 340
# train EOS: 0. TRAIN_1.bmp
# train EOS: 1. TRAIN_2.bmp
# train EOS: 2. TRAIN_3.bmp
# train EOS: 3. TRAIN_4.bmp
# train EOS: 4. TRAIN_5.bmp
# train EOS: 5. TRAIN_6.bmp
# train EOS: 6. TRAIN_7.bmp
# train EOS: 7. TRAIN_8.bmp
# train EOS: 8. TRAIN_9.bmp
# train EOS: 9. TRAIN_10.bmp
# train EOS: 10. TRAIN_11.bmp
# train EOS: 11. TRAIN_12.bmp
# train EOS: 12. TRAIN_13.bmp
# train EOS: 13. TRAIN_14.bmp
# train EOS: 14. TRAIN_15.bmp
# train EOS: 15. TRAIN_16.bmp
# train EOS: 16. TRAIN_17.bmp
# train EOS: 17. TRAIN_18.bmp
# train EOS: 18. TRAIN_19.bmp
# train EOS: 19. TRAIN_20.bmp
# train EOS: 20. TRAIN_21.bmp
# train EOS: 21. TRAIN_22.bmp
# train EOS: 22. TRAIN_23.bmp
# train EOS: 23. TRAIN_24.bmp
# train EOS: 24. TRAIN_25.bmp
# train EOS: 25. TRAIN_26.bmp
# train EOS: 26. TRAIN_27.bmp
# train EOS: 27. TRAIN_28.bmp
# train EOS: 28. TRAIN_29.bmp
# train EOS: 29. TRAIN_30.bmp
# train EOS: 30. TRAIN_31.bmp
# train EOS: 31. TRAIN_32.bmp
# train EOS: 32. TRAIN_33.bmp
# train EOS: 33. TRAIN_34.bmp
# train EOS: 34. TRAIN_35.bmp
# train EOS: 35. TRAIN_36.bmp
# train EOS: 36. TRAIN_37.bmp
# train EOS: 37. TRAIN_38.bmp
# train EOS: 38. TRAIN_39.bmp
# train EOS: 39. TRAIN_40.bmp
# train EOS: 40. TRAIN_41.bmp
# train EOS: 41. TRAIN_42.bmp
# train EOS: 42. TRAIN_43.bmp
# train EOS: 43. TRAIN_44.bmp
# train EOS: 44. TRAIN_45.bmp
bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/validation/EOS
# 42
# validation EOS: 0. VAL_1.bmp
# validation EOS: 1. VAL_2.bmp
# validation EOS: 2. VAL_3.bmp
# validation EOS: 3. VAL_4.bmp
# validation EOS: 4. VAL_5.bmp
# validation EOS: 5. VAL_6.bmp
# validation EOS: 6. VAL_7.bmp
# validation EOS: 7. VAL_8.bmp
# validation EOS: 8. VAL_9.bmp
# validation EOS: 9. VAL_10.bmp
# validation EOS: 10. VAL_11.bmp
# validation EOS: 11. VAL_12.bmp
# validation EOS: 12. VAL_13.bmp
# validation EOS: 13. VAL_14.bmp
# validation EOS: 14. VAL_15.bmp
# validation EOS: 15. VAL_16.bmp
# validation EOS: 16. VAL_17.bmp
# validation EOS: 17. VAL_18.bmp
# validation EOS: 18. VAL_19.bmp
# validation EOS: 19. VAL_20.bmp
# validation EOS: 20. VAL_21.bmp
# validation EOS: 21. VAL_22.bmp
# validation EOS: 22. VAL_23.bmp
# validation EOS: 23. VAL_24.bmp
# validation EOS: 24. VAL_25.bmp
# validation EOS: 25. VAL_26.bmp
# validation EOS: 26. VAL_27.bmp
# validation EOS: 27. VAL_28.bmp
# validation EOS: 28. VAL_29.bmp
# validation EOS: 29. VAL_30.bmp
# validation EOS: 30. VAL_31.bmp
# validation EOS: 31. VAL_32.bmp
# validation EOS: 32. VAL_33.bmp
# validation EOS: 33. VAL_34.bmp
# validation EOS: 34. VAL_35.bmp
# validation EOS: 35. VAL_36.bmp
# validation EOS: 36. VAL_37.bmp
# validation EOS: 37. VAL_38.bmp
# validation EOS: 38. VAL_39.bmp
# validation EOS: 39. VAL_40.bmp
# validation EOS: 40. VAL_41.bmp
# validation EOS: 41. VAL_42.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/test/EOS
# 42
# test EOS: 0. TEST_1.bmp
# test EOS: 1. TEST_2.bmp
# test EOS: 2. TEST_3.bmp
# test EOS: 3. TEST_4.bmp
# test EOS: 4. TEST_5.bmp
# test EOS: 5. TEST_6.bmp
# test EOS: 6. TEST_7.bmp
# test EOS: 7. TEST_8.bmp
# test EOS: 8. TEST_9.bmp
# test EOS: 9. TEST_10.bmp
# test EOS: 10. TEST_11.bmp
# test EOS: 11. TEST_12.bmp
# test EOS: 12. TEST_13.bmp
# test EOS: 13. TEST_14.bmp
# test EOS: 14. TEST_15.bmp
# test EOS: 15. TEST_16.bmp
# test EOS: 16. TEST_17.bmp
# test EOS: 17. TEST_18.bmp
# test EOS: 18. TEST_19.bmp
# test EOS: 19. TEST_20.bmp
# test EOS: 20. TEST_21.bmp
# test EOS: 21. TEST_22.bmp
# test EOS: 22. TEST_23.bmp
# test EOS: 23. TEST_24.bmp
# test EOS: 24. TEST_25.bmp
# test EOS: 25. TEST_26.bmp
# test EOS: 26. TEST_27.bmp
# test EOS: 27. TEST_28.bmp
# test EOS: 28. TEST_29.bmp
# test EOS: 29. TEST_30.bmp
# test EOS: 30. TEST_31.bmp
# test EOS: 31. TEST_32.bmp
# test EOS: 32. TEST_33.bmp
# test EOS: 33. TEST_34.bmp
# test EOS: 34. TEST_35.bmp
# test EOS: 35. TEST_36.bmp
# test EOS: 36. TEST_37.bmp
# test EOS: 37. TEST_38.bmp
# test EOS: 38. TEST_39.bmp
# test EOS: 39. TEST_40.bmp
# test EOS: 40. TEST_41.bmp
# test EOS: 41. TEST_42.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/train/KSC
# 13
# train KSC: 0. TRAIN_1.bmp
# train KSC: 1. TRAIN_2.bmp
# train KSC: 2. TRAIN_3.bmp
# train KSC: 3. TRAIN_4.bmp
# train KSC: 4. TRAIN_5.bmp
# train KSC: 5. TRAIN_6.bmp
# train KSC: 6. TRAIN_7.bmp
# train KSC: 7. TRAIN_8.bmp
# train KSC: 8. TRAIN_9.bmp
# train KSC: 9. TRAIN_10.bmp
# train KSC: 10. TRAIN_11.bmp
# train KSC: 11. TRAIN_12.bmp
# train KSC: 12. TRAIN_13.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/validation/KSC
# 1
# validation KSC: 0. VAL_1.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/test/KSC
# 1
# test KSC: 0. TEST_1.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/train/LYA
# 9
# train LYA: 0. TRAIN_1.bmp
# train LYA: 1. TRAIN_2.bmp
# train LYA: 2. TRAIN_3.bmp
# train LYA: 3. TRAIN_4.bmp
# train LYA: 4. TRAIN_5.bmp
# train LYA: 5. TRAIN_6.bmp
# train LYA: 6. TRAIN_7.bmp
# train LYA: 7. TRAIN_8.bmp
# train LYA: 8. TRAIN_9.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/validation/LYA
# 1
# validation LYA: 0. VAL_1.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/test/LYA
# 1
# test LYA: 0. TEST_1.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/train/LYT
# 801
# train LYT: 0. TRAIN_1.bmp
# train LYT: 1. TRAIN_2.bmp
# train LYT: 2. TRAIN_3.bmp
# train LYT: 3. TRAIN_4.bmp
# train LYT: 4. TRAIN_5.bmp
# train LYT: 5. TRAIN_6.bmp
# train LYT: 6. TRAIN_7.bmp
# train LYT: 7. TRAIN_8.bmp
# train LYT: 8. TRAIN_9.bmp
# train LYT: 9. TRAIN_10.bmp
# train LYT: 10. TRAIN_11.bmp
# train LYT: 11. TRAIN_12.bmp
# train LYT: 12. TRAIN_13.bmp
# train LYT: 13. TRAIN_14.bmp
# train LYT: 14. TRAIN_15.bmp
# train LYT: 15. TRAIN_16.bmp
# train LYT: 16. TRAIN_17.bmp
# train LYT: 17. TRAIN_18.bmp
# train LYT: 18. TRAIN_19.bmp
# train LYT: 19. TRAIN_20.bmp
# train LYT: 20. TRAIN_21.bmp
# train LYT: 21. TRAIN_22.bmp
# train LYT: 22. TRAIN_23.bmp
# train LYT: 23. TRAIN_24.bmp
# train LYT: 24. TRAIN_25.bmp
# train LYT: 25. TRAIN_26.bmp
# train LYT: 26. TRAIN_27.bmp
# train LYT: 27. TRAIN_28.bmp
# train LYT: 28. TRAIN_29.bmp
# train LYT: 29. TRAIN_30.bmp
# train LYT: 30. TRAIN_31.bmp
# train LYT: 31. TRAIN_32.bmp
# train LYT: 32. TRAIN_33.bmp
# train LYT: 33. TRAIN_34.bmp
# train LYT: 34. TRAIN_35.bmp
# train LYT: 35. TRAIN_36.bmp
# train LYT: 36. TRAIN_37.bmp
# train LYT: 183. TRAIN_184.bmp
# train LYT: 184. TRAIN_185.bmp
# train LYT: 185. TRAIN_186.bmp
# train LYT: 186. TRAIN_187.bmp
# train LYT: 187. TRAIN_188.bmp
# train LYT: 188. TRAIN_189.bmp
# train LYT: 189. TRAIN_190.bmp
# train LYT: 190. TRAIN_191.bmp
# train LYT: 191. TRAIN_192.bmp
# train LYT: 192. TRAIN_193.bmp
# train LYT: 193. TRAIN_194.bmp
# train LYT: 194. TRAIN_195.bmp
# train LYT: 195. TRAIN_196.bmp
# train LYT: 196. TRAIN_197.bmp
# train LYT: 197. TRAIN_198.bmp
# train LYT: 198. TRAIN_199.bmp
# train LYT: 199. TRAIN_200.bmp
# train LYT: 200. TRAIN_201.bmp
# train LYT: 201. TRAIN_202.bmp
# train LYT: 202. TRAIN_203.bmp
# train LYT: 203. TRAIN_204.bmp
# train LYT: 204. TRAIN_205.bmp
# train LYT: 205. TRAIN_206.bmp
# train LYT: 206. TRAIN_207.bmp
# train LYT: 207. TRAIN_208.bmp
# train LYT: 208. TRAIN_209.bmp
# train LYT: 209. TRAIN_210.bmp
# train LYT: 210. TRAIN_211.bmp
# train LYT: 211. TRAIN_212.bmp
# train LYT: 212. TRAIN_213.bmp
# train LYT: 213. TRAIN_214.bmp
# train LYT: 214. TRAIN_215.bmp
# train LYT: 215. TRAIN_216.bmp
# train LYT: 216. TRAIN_217.bmp
# train LYT: 217. TRAIN_218.bmp
# train LYT: 218. TRAIN_219.bmp
# train LYT: 219. TRAIN_220.bmp
# train LYT: 220. TRAIN_221.bmp
# train LYT: 221. TRAIN_222.bmp
# train LYT: 222. TRAIN_223.bmp
# train LYT: 223. TRAIN_224.bmp
# train LYT: 224. TRAIN_225.bmp
# train LYT: 225. TRAIN_226.bmp
# train LYT: 226. TRAIN_227.bmp
# train LYT: 227. TRAIN_228.bmp
# train LYT: 228. TRAIN_229.bmp
# train LYT: 229. TRAIN_230.bmp
# train LYT: 230. TRAIN_231.bmp
# train LYT: 231. TRAIN_232.bmp
# train LYT: 232. TRAIN_233.bmp
# train LYT: 233. TRAIN_234.bmp
# train LYT: 234. TRAIN_235.bmp
# train LYT: 235. TRAIN_236.bmp
# train LYT: 236. TRAIN_237.bmp
# train LYT: 237. TRAIN_238.bmp
# train LYT: 238. TRAIN_239.bmp
# train LYT: 239. TRAIN_240.bmp
# train LYT: 240. TRAIN_241.bmp
# train LYT: 241. TRAIN_242.bmp
# train LYT: 242. TRAIN_243.bmp
# train LYT: 243. TRAIN_244.bmp
# train LYT: 244. TRAIN_245.bmp
# train LYT: 245. TRAIN_246.bmp
# train LYT: 246. TRAIN_247.bmp
# train LYT: 247. TRAIN_248.bmp
# train LYT: 248. TRAIN_249.bmp
# train LYT: 249. TRAIN_250.bmp
# train LYT: 250. TRAIN_251.bmp
# train LYT: 251. TRAIN_252.bmp
# train LYT: 252. TRAIN_253.bmp
# train LYT: 253. TRAIN_254.bmp
# train LYT: 254. TRAIN_255.bmp
# train LYT: 255. TRAIN_256.bmp
# train LYT: 329. TRAIN_330.bmp
# train LYT: 330. TRAIN_331.bmp
# train LYT: 331. TRAIN_332.bmp
# train LYT: 332. TRAIN_333.bmp
# train LYT: 333. TRAIN_334.bmp
# train LYT: 334. TRAIN_335.bmp
# train LYT: 335. TRAIN_336.bmp
# train LYT: 336. TRAIN_337.bmp
# train LYT: 337. TRAIN_338.bmp
# train LYT: 338. TRAIN_339.bmp
# train LYT: 339. TRAIN_340.bmp
# train LYT: 340. TRAIN_341.bmp
# train LYT: 341. TRAIN_342.bmp
# train LYT: 342. TRAIN_343.bmp
# train LYT: 343. TRAIN_344.bmp
# train LYT: 344. TRAIN_345.bmp
# train LYT: 345. TRAIN_346.bmp
# train LYT: 346. TRAIN_347.bmp
# train LYT: 347. TRAIN_348.bmp
# train LYT: 348. TRAIN_349.bmp
# train LYT: 349. TRAIN_350.bmp
# train LYT: 350. TRAIN_351.bmp
# train LYT: 351. TRAIN_352.bmp
# train LYT: 352. TRAIN_353.bmp
# train LYT: 353. TRAIN_354.bmp
# train LYT: 354. TRAIN_355.bmp
# train LYT: 355. TRAIN_356.bmp
# train LYT: 356. TRAIN_357.bmp
# train LYT: 357. TRAIN_358.bmp
# train LYT: 358. TRAIN_359.bmp
# train LYT: 359. TRAIN_360.bmp
# train LYT: 360. TRAIN_361.bmp
# train LYT: 361. TRAIN_362.bmp
# train LYT: 362. TRAIN_363.bmp
# train LYT: 363. TRAIN_364.bmp
# train LYT: 364. TRAIN_365.bmp
# train LYT: 365. TRAIN_366.bmp
# train LYT: 366. TRAIN_367.bmp
# train LYT: 367. TRAIN_368.bmp
# train LYT: 368. TRAIN_369.bmp
# train LYT: 369. TRAIN_370.bmp
# train LYT: 370. TRAIN_371.bmp
# train LYT: 371. TRAIN_372.bmp
# train LYT: 372. TRAIN_373.bmp
# train LYT: 373. TRAIN_374.bmp
# train LYT: 374. TRAIN_375.bmp
# train LYT: 375. TRAIN_376.bmp
# train LYT: 376. TRAIN_377.bmp
# train LYT: 377. TRAIN_378.bmp
# train LYT: 378. TRAIN_379.bmp
# train LYT: 379. TRAIN_380.bmp
# train LYT: 380. TRAIN_381.bmp
# train LYT: 381. TRAIN_382.bmp
# train LYT: 382. TRAIN_383.bmp
# train LYT: 383. TRAIN_384.bmp
# train LYT: 384. TRAIN_385.bmp
# train LYT: 385. TRAIN_386.bmp
# train LYT: 386. TRAIN_387.bmp
# train LYT: 387. TRAIN_388.bmp
# train LYT: 388. TRAIN_389.bmp
# train LYT: 389. TRAIN_390.bmp
# train LYT: 390. TRAIN_391.bmp
# train LYT: 391. TRAIN_392.bmp
# train LYT: 392. TRAIN_393.bmp
# train LYT: 393. TRAIN_394.bmp
# train LYT: 394. TRAIN_395.bmp
# train LYT: 395. TRAIN_396.bmp
# train LYT: 396. TRAIN_397.bmp
# train LYT: 397. TRAIN_398.bmp
# train LYT: 398. TRAIN_399.bmp
# train LYT: 399. TRAIN_400.bmp
# train LYT: 400. TRAIN_401.bmp
# train LYT: 401. TRAIN_402.bmp
# train LYT: 402. TRAIN_403.bmp
# train LYT: 476. TRAIN_477.bmp
# train LYT: 477. TRAIN_478.bmp
# train LYT: 478. TRAIN_479.bmp
# train LYT: 479. TRAIN_480.bmp
# train LYT: 480. TRAIN_481.bmp
# train LYT: 481. TRAIN_482.bmp
# train LYT: 482. TRAIN_483.bmp
# train LYT: 483. TRAIN_484.bmp
# train LYT: 484. TRAIN_485.bmp
# train LYT: 485. TRAIN_486.bmp
# train LYT: 486. TRAIN_487.bmp
# train LYT: 487. TRAIN_488.bmp
# train LYT: 488. TRAIN_489.bmp
# train LYT: 489. TRAIN_490.bmp
# train LYT: 490. TRAIN_491.bmp
# train LYT: 491. TRAIN_492.bmp
# train LYT: 492. TRAIN_493.bmp
# train LYT: 493. TRAIN_494.bmp
# train LYT: 494. TRAIN_495.bmp
# train LYT: 495. TRAIN_496.bmp
# train LYT: 496. TRAIN_497.bmp
# train LYT: 497. TRAIN_498.bmp
# train LYT: 498. TRAIN_499.bmp
# train LYT: 499. TRAIN_500.bmp
# train LYT: 500. TRAIN_501.bmp
# train LYT: 501. TRAIN_502.bmp
# train LYT: 502. TRAIN_503.bmp
# train LYT: 503. TRAIN_504.bmp
# train LYT: 504. TRAIN_505.bmp
# train LYT: 505. TRAIN_506.bmp
# train LYT: 506. TRAIN_507.bmp
# train LYT: 507. TRAIN_508.bmp
# train LYT: 508. TRAIN_509.bmp
# train LYT: 509. TRAIN_510.bmp
# train LYT: 510. TRAIN_511.bmp
# train LYT: 511. TRAIN_512.bmp
# train LYT: 512. TRAIN_513.bmp
# train LYT: 513. TRAIN_514.bmp
# train LYT: 514. TRAIN_515.bmp
# train LYT: 515. TRAIN_516.bmp
# train LYT: 516. TRAIN_517.bmp
# train LYT: 517. TRAIN_518.bmp
# train LYT: 518. TRAIN_519.bmp
# train LYT: 519. TRAIN_520.bmp
# train LYT: 520. TRAIN_521.bmp
# train LYT: 521. TRAIN_522.bmp
# train LYT: 522. TRAIN_523.bmp
# train LYT: 523. TRAIN_524.bmp
# train LYT: 524. TRAIN_525.bmp
# train LYT: 525. TRAIN_526.bmp
# train LYT: 526. TRAIN_527.bmp
# train LYT: 527. TRAIN_528.bmp
# train LYT: 528. TRAIN_529.bmp
# train LYT: 529. TRAIN_530.bmp
# train LYT: 530. TRAIN_531.bmp
# train LYT: 531. TRAIN_532.bmp
# train LYT: 532. TRAIN_533.bmp
# train LYT: 533. TRAIN_534.bmp
# train LYT: 534. TRAIN_535.bmp
# train LYT: 535. TRAIN_536.bmp
# train LYT: 536. TRAIN_537.bmp
# train LYT: 537. TRAIN_538.bmp
# train LYT: 538. TRAIN_539.bmp
# train LYT: 539. TRAIN_540.bmp
# train LYT: 540. TRAIN_541.bmp
# train LYT: 541. TRAIN_542.bmp
# train LYT: 542. TRAIN_543.bmp
# train LYT: 543. TRAIN_544.bmp
# train LYT: 544. TRAIN_545.bmp
# train LYT: 545. TRAIN_546.bmp
# train LYT: 546. TRAIN_547.bmp
# train LYT: 547. TRAIN_548.bmp
# train LYT: 548. TRAIN_549.bmp
# train LYT: 549. TRAIN_550.bmp
# train LYT: 550. TRAIN_551.bmp
# train LYT: 551. TRAIN_552.bmp
# train LYT: 552. TRAIN_553.bmp
# train LYT: 553. TRAIN_554.bmp
# train LYT: 554. TRAIN_555.bmp
# train LYT: 555. TRAIN_556.bmp
# train LYT: 556. TRAIN_557.bmp
# train LYT: 557. TRAIN_558.bmp
# train LYT: 558. TRAIN_559.bmp
# train LYT: 559. TRAIN_560.bmp
# train LYT: 560. TRAIN_561.bmp
# train LYT: 561. TRAIN_562.bmp
# train LYT: 562. TRAIN_563.bmp
# train LYT: 563. TRAIN_564.bmp
# train LYT: 564. TRAIN_565.bmp
# train LYT: 565. TRAIN_566.bmp
# train LYT: 566. TRAIN_567.bmp
# train LYT: 567. TRAIN_568.bmp
# train LYT: 568. TRAIN_569.bmp
# train LYT: 569. TRAIN_570.bmp
# train LYT: 570. TRAIN_571.bmp
# train LYT: 571. TRAIN_572.bmp
# train LYT: 572. TRAIN_573.bmp
# train LYT: 573. TRAIN_574.bmp
# train LYT: 574. TRAIN_575.bmp
# train LYT: 575. TRAIN_576.bmp
# train LYT: 576. TRAIN_577.bmp
# train LYT: 577. TRAIN_578.bmp
# train LYT: 578. TRAIN_579.bmp
# train LYT: 579. TRAIN_580.bmp
# train LYT: 580. TRAIN_581.bmp
# train LYT: 581. TRAIN_582.bmp
# train LYT: 582. TRAIN_583.bmp
# train LYT: 583. TRAIN_584.bmp
# train LYT: 584. TRAIN_585.bmp
# train LYT: 585. TRAIN_586.bmp
# train LYT: 586. TRAIN_587.bmp
# train LYT: 587. TRAIN_588.bmp
# train LYT: 588. TRAIN_589.bmp
# train LYT: 589. TRAIN_590.bmp
# train LYT: 590. TRAIN_591.bmp
# train LYT: 591. TRAIN_592.bmp
# train LYT: 592. TRAIN_593.bmp
# train LYT: 593. TRAIN_594.bmp
# train LYT: 594. TRAIN_595.bmp
# train LYT: 595. TRAIN_596.bmp
# train LYT: 596. TRAIN_597.bmp
# train LYT: 597. TRAIN_598.bmp
# train LYT: 598. TRAIN_599.bmp
# train LYT: 599. TRAIN_600.bmp
# train LYT: 600. TRAIN_601.bmp
# train LYT: 601. TRAIN_602.bmp
# train LYT: 602. TRAIN_603.bmp
# train LYT: 603. TRAIN_604.bmp
# train LYT: 604. TRAIN_605.bmp
# train LYT: 605. TRAIN_606.bmp
# train LYT: 606. TRAIN_607.bmp
# train LYT: 607. TRAIN_608.bmp
# train LYT: 608. TRAIN_609.bmp
# train LYT: 609. TRAIN_610.bmp
# train LYT: 610. TRAIN_611.bmp
# train LYT: 611. TRAIN_612.bmp
# train LYT: 612. TRAIN_613.bmp
# train LYT: 613. TRAIN_614.bmp
# train LYT: 614. TRAIN_615.bmp
# train LYT: 615. TRAIN_616.bmp
# train LYT: 616. TRAIN_617.bmp
# train LYT: 617. TRAIN_618.bmp
# train LYT: 618. TRAIN_619.bmp
# train LYT: 619. TRAIN_620.bmp
# train LYT: 620. TRAIN_621.bmp
# train LYT: 621. TRAIN_622.bmp
# train LYT: 622. TRAIN_623.bmp
# train LYT: 623. TRAIN_624.bmp
# train LYT: 624. TRAIN_625.bmp
# train LYT: 625. TRAIN_626.bmp
# train LYT: 626. TRAIN_627.bmp
# train LYT: 627. TRAIN_628.bmp
# train LYT: 628. TRAIN_629.bmp
# train LYT: 629. TRAIN_630.bmp
# train LYT: 630. TRAIN_631.bmp
# train LYT: 631. TRAIN_632.bmp
# train LYT: 632. TRAIN_633.bmp
# train LYT: 633. TRAIN_634.bmp
# train LYT: 634. TRAIN_635.bmp
# train LYT: 635. TRAIN_636.bmp
# train LYT: 636. TRAIN_637.bmp
# train LYT: 637. TRAIN_638.bmp
# train LYT: 638. TRAIN_639.bmp
# train LYT: 639. TRAIN_640.bmp
# train LYT: 640. TRAIN_641.bmp
# train LYT: 641. TRAIN_642.bmp
# train LYT: 642. TRAIN_643.bmp
# train LYT: 643. TRAIN_644.bmp
# train LYT: 644. TRAIN_645.bmp
# train LYT: 645. TRAIN_646.bmp
# train LYT: 646. TRAIN_647.bmp
# train LYT: 647. TRAIN_648.bmp
# train LYT: 648. TRAIN_649.bmp
# train LYT: 649. TRAIN_650.bmp
# train LYT: 650. TRAIN_651.bmp
# train LYT: 651. TRAIN_652.bmp
# train LYT: 652. TRAIN_653.bmp
# train LYT: 653. TRAIN_654.bmp
# train LYT: 654. TRAIN_655.bmp
# train LYT: 655. TRAIN_656.bmp
# train LYT: 656. TRAIN_657.bmp
# train LYT: 657. TRAIN_658.bmp
# train LYT: 658. TRAIN_659.bmp
# train LYT: 659. TRAIN_660.bmp
# train LYT: 660. TRAIN_661.bmp
# train LYT: 661. TRAIN_662.bmp
# train LYT: 662. TRAIN_663.bmp
# train LYT: 663. TRAIN_664.bmp
# train LYT: 664. TRAIN_665.bmp
# train LYT: 665. TRAIN_666.bmp
# train LYT: 666. TRAIN_667.bmp
# train LYT: 667. TRAIN_668.bmp
# train LYT: 668. TRAIN_669.bmp
# train LYT: 669. TRAIN_670.bmp
# train LYT: 670. TRAIN_671.bmp
# train LYT: 671. TRAIN_672.bmp
# train LYT: 672. TRAIN_673.bmp
# train LYT: 673. TRAIN_674.bmp
# train LYT: 674. TRAIN_675.bmp
# train LYT: 675. TRAIN_676.bmp
# train LYT: 676. TRAIN_677.bmp
# train LYT: 677. TRAIN_678.bmp
# train LYT: 678. TRAIN_679.bmp
# train LYT: 679. TRAIN_680.bmp
# train LYT: 680. TRAIN_681.bmp
# train LYT: 681. TRAIN_682.bmp
# train LYT: 682. TRAIN_683.bmp
# train LYT: 683. TRAIN_684.bmp
# train LYT: 684. TRAIN_685.bmp
# train LYT: 685. TRAIN_686.bmp
# train LYT: 686. TRAIN_687.bmp
# train LYT: 687. TRAIN_688.bmp
# train LYT: 688. TRAIN_689.bmp
# train LYT: 689. TRAIN_690.bmp
# train LYT: 690. TRAIN_691.bmp
# train LYT: 691. TRAIN_692.bmp
# train LYT: 692. TRAIN_693.bmp
# train LYT: 693. TRAIN_694.bmp
# train LYT: 694. TRAIN_695.bmp
# train LYT: 695. TRAIN_696.bmp
# train LYT: 696. TRAIN_697.bmp
# train LYT: 697. TRAIN_698.bmp
# train LYT: 698. TRAIN_699.bmp
# train LYT: 699. TRAIN_700.bmp
# train LYT: 700. TRAIN_701.bmp
# train LYT: 701. TRAIN_702.bmp
# train LYT: 702. TRAIN_703.bmp
# train LYT: 703. TRAIN_704.bmp
# train LYT: 704. TRAIN_705.bmp
# train LYT: 705. TRAIN_706.bmp
# train LYT: 706. TRAIN_707.bmp
# train LYT: 707. TRAIN_708.bmp
# train LYT: 708. TRAIN_709.bmp
# train LYT: 709. TRAIN_710.bmp
# train LYT: 710. TRAIN_711.bmp
# train LYT: 711. TRAIN_712.bmp
# train LYT: 712. TRAIN_713.bmp
# train LYT: 713. TRAIN_714.bmp
# train LYT: 714. TRAIN_715.bmp
# train LYT: 715. TRAIN_716.bmp
# train LYT: 716. TRAIN_717.bmp
# train LYT: 717. TRAIN_718.bmp
# train LYT: 718. TRAIN_719.bmp
# train LYT: 719. TRAIN_720.bmp
# train LYT: 720. TRAIN_721.bmp
# train LYT: 721. TRAIN_722.bmp
# train LYT: 722. TRAIN_723.bmp
# train LYT: 723. TRAIN_724.bmp
# train LYT: 724. TRAIN_725.bmp
# train LYT: 725. TRAIN_726.bmp
# train LYT: 726. TRAIN_727.bmp
# train LYT: 727. TRAIN_728.bmp
# train LYT: 728. TRAIN_729.bmp
# train LYT: 729. TRAIN_730.bmp
# train LYT: 730. TRAIN_731.bmp
# train LYT: 731. TRAIN_732.bmp
# train LYT: 732. TRAIN_733.bmp
# train LYT: 733. TRAIN_734.bmp
# train LYT: 734. TRAIN_735.bmp
# train LYT: 735. TRAIN_736.bmp
# train LYT: 736. TRAIN_737.bmp
# train LYT: 737. TRAIN_738.bmp
# train LYT: 738. TRAIN_739.bmp
# train LYT: 739. TRAIN_740.bmp
# train LYT: 740. TRAIN_741.bmp
# train LYT: 741. TRAIN_742.bmp
# train LYT: 742. TRAIN_743.bmp
# train LYT: 743. TRAIN_744.bmp
# train LYT: 744. TRAIN_745.bmp
# train LYT: 745. TRAIN_746.bmp
# train LYT: 746. TRAIN_747.bmp
# train LYT: 747. TRAIN_748.bmp
# train LYT: 748. TRAIN_749.bmp
# train LYT: 749. TRAIN_750.bmp
# train LYT: 750. TRAIN_751.bmp
# train LYT: 751. TRAIN_752.bmp
# train LYT: 752. TRAIN_753.bmp
# train LYT: 753. TRAIN_754.bmp
# train LYT: 754. TRAIN_755.bmp
# train LYT: 755. TRAIN_756.bmp
# train LYT: 756. TRAIN_757.bmp
# train LYT: 757. TRAIN_758.bmp
# train LYT: 758. TRAIN_759.bmp
# train LYT: 759. TRAIN_760.bmp
# train LYT: 760. TRAIN_761.bmp
# train LYT: 761. TRAIN_762.bmp
# train LYT: 762. TRAIN_763.bmp
# train LYT: 763. TRAIN_764.bmp
# train LYT: 764. TRAIN_765.bmp
# train LYT: 765. TRAIN_766.bmp
# train LYT: 766. TRAIN_767.bmp
# train LYT: 767. TRAIN_768.bmp
# train LYT: 768. TRAIN_769.bmp
# train LYT: 769. TRAIN_770.bmp
# train LYT: 770. TRAIN_771.bmp
# train LYT: 771. TRAIN_772.bmp
# train LYT: 772. TRAIN_773.bmp
# train LYT: 773. TRAIN_774.bmp
# train LYT: 774. TRAIN_775.bmp
# train LYT: 775. TRAIN_776.bmp
# train LYT: 776. TRAIN_777.bmp
# train LYT: 777. TRAIN_778.bmp
# train LYT: 778. TRAIN_779.bmp
# train LYT: 779. TRAIN_780.bmp
# train LYT: 780. TRAIN_781.bmp
# train LYT: 781. TRAIN_782.bmp
# train LYT: 782. TRAIN_783.bmp
# train LYT: 783. TRAIN_784.bmp
# train LYT: 784. TRAIN_785.bmp
# train LYT: 785. TRAIN_786.bmp
# train LYT: 786. TRAIN_787.bmp
# train LYT: 787. TRAIN_788.bmp
# train LYT: 788. TRAIN_789.bmp
# train LYT: 789. TRAIN_790.bmp
# train LYT: 790. TRAIN_791.bmp
# train LYT: 791. TRAIN_792.bmp
# train LYT: 792. TRAIN_793.bmp
# train LYT: 793. TRAIN_794.bmp
# train LYT: 794. TRAIN_795.bmp
# train LYT: 795. TRAIN_796.bmp
# train LYT: 796. TRAIN_797.bmp
# train LYT: 797. TRAIN_798.bmp
# train LYT: 798. TRAIN_799.bmp
# train LYT: 799. TRAIN_800.bmp
# train LYT: 800. TRAIN_801.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/validation/LYT
# 100
# validation LYT: 0. VAL_1.bmp
# validation LYT: 1. VAL_2.bmp
# validation LYT: 2. VAL_3.bmp
# validation LYT: 3. VAL_4.bmp
# validation LYT: 4. VAL_5.bmp
# validation LYT: 5. VAL_6.bmp
# validation LYT: 6. VAL_7.bmp
# validation LYT: 7. VAL_8.bmp
# validation LYT: 8. VAL_9.bmp
# validation LYT: 9. VAL_10.bmp
# validation LYT: 10. VAL_11.bmp
# validation LYT: 11. VAL_12.bmp
# validation LYT: 12. VAL_13.bmp
# validation LYT: 13. VAL_14.bmp
# validation LYT: 14. VAL_15.bmp
# validation LYT: 15. VAL_16.bmp
# validation LYT: 16. VAL_17.bmp
# validation LYT: 17. VAL_18.bmp
# validation LYT: 18. VAL_19.bmp
# validation LYT: 19. VAL_20.bmp
# validation LYT: 20. VAL_21.bmp
# validation LYT: 21. VAL_22.bmp
# validation LYT: 22. VAL_23.bmp
# validation LYT: 23. VAL_24.bmp
# validation LYT: 24. VAL_25.bmp
# validation LYT: 25. VAL_26.bmp
# validation LYT: 26. VAL_27.bmp
# validation LYT: 27. VAL_28.bmp
# validation LYT: 28. VAL_29.bmp
# validation LYT: 29. VAL_30.bmp
# validation LYT: 30. VAL_31.bmp
# validation LYT: 31. VAL_32.bmp
# validation LYT: 32. VAL_33.bmp
# validation LYT: 33. VAL_34.bmp
# validation LYT: 34. VAL_35.bmp
# validation LYT: 35. VAL_36.bmp
# validation LYT: 36. VAL_37.bmp
# validation LYT: 37. VAL_38.bmp
# validation LYT: 38. VAL_39.bmp
# validation LYT: 39. VAL_40.bmp
# validation LYT: 40. VAL_41.bmp
# validation LYT: 41. VAL_42.bmp
# validation LYT: 42. VAL_43.bmp
# validation LYT: 43. VAL_44.bmp
# validation LYT: 44. VAL_45.bmp
# validation LYT: 45. VAL_46.bmp
# validation LYT: 46. VAL_47.bmp
# validation LYT: 47. VAL_48.bmp
# validation LYT: 48. VAL_49.bmp
# validation LYT: 49. VAL_50.bmp
# validation LYT: 50. VAL_51.bmp
# validation LYT: 51. VAL_52.bmp
# validation LYT: 52. VAL_53.bmp
# validation LYT: 53. VAL_54.bmp
# validation LYT: 54. VAL_55.bmp
# validation LYT: 55. VAL_56.bmp
# validation LYT: 56. VAL_57.bmp
# validation LYT: 57. VAL_58.bmp
# validation LYT: 58. VAL_59.bmp
# validation LYT: 59. VAL_60.bmp
# validation LYT: 60. VAL_61.bmp
# validation LYT: 61. VAL_62.bmp
# validation LYT: 62. VAL_63.bmp
# validation LYT: 63. VAL_64.bmp
# validation LYT: 64. VAL_65.bmp
# validation LYT: 65. VAL_66.bmp
# validation LYT: 66. VAL_67.bmp
# validation LYT: 67. VAL_68.bmp
# validation LYT: 68. VAL_69.bmp
# validation LYT: 69. VAL_70.bmp
# validation LYT: 70. VAL_71.bmp
# validation LYT: 71. VAL_72.bmp
# validation LYT: 72. VAL_73.bmp
# validation LYT: 73. VAL_74.bmp
# validation LYT: 74. VAL_75.bmp
# validation LYT: 75. VAL_76.bmp
# validation LYT: 76. VAL_77.bmp
# validation LYT: 77. VAL_78.bmp
# validation LYT: 78. VAL_79.bmp
# validation LYT: 79. VAL_80.bmp
# validation LYT: 80. VAL_81.bmp
# validation LYT: 81. VAL_82.bmp
# validation LYT: 82. VAL_83.bmp
# validation LYT: 83. VAL_84.bmp
# validation LYT: 84. VAL_85.bmp
# validation LYT: 85. VAL_86.bmp
# validation LYT: 86. VAL_87.bmp
# validation LYT: 87. VAL_88.bmp
# validation LYT: 88. VAL_89.bmp
# validation LYT: 89. VAL_90.bmp
# validation LYT: 90. VAL_91.bmp
# validation LYT: 91. VAL_92.bmp
# validation LYT: 92. VAL_93.bmp
# validation LYT: 93. VAL_94.bmp
# validation LYT: 94. VAL_95.bmp
# validation LYT: 95. VAL_96.bmp
# validation LYT: 96. VAL_97.bmp
# validation LYT: 97. VAL_98.bmp
# validation LYT: 98. VAL_99.bmp
# validation LYT: 99. VAL_100.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/test/LYT
# 100
# test LYT: 0. TEST_1.bmp
# test LYT: 1. TEST_2.bmp
# test LYT: 2. TEST_3.bmp
# test LYT: 3. TEST_4.bmp
# test LYT: 4. TEST_5.bmp
# test LYT: 5. TEST_6.bmp
# test LYT: 6. TEST_7.bmp
# test LYT: 7. TEST_8.bmp
# test LYT: 8. TEST_9.bmp
# test LYT: 9. TEST_10.bmp
# test LYT: 10. TEST_11.bmp
# test LYT: 11. TEST_12.bmp
# test LYT: 12. TEST_13.bmp
# test LYT: 13. TEST_14.bmp
# test LYT: 14. TEST_15.bmp
# test LYT: 15. TEST_16.bmp
# test LYT: 16. TEST_17.bmp
# test LYT: 17. TEST_18.bmp
# test LYT: 18. TEST_19.bmp
# test LYT: 19. TEST_20.bmp
bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/train/PMO
# 56
# train PMO: 0. TRAIN_1.bmp
# train PMO: 1. TRAIN_2.bmp
# train PMO: 2. TRAIN_3.bmp
# train PMO: 3. TRAIN_4.bmp
# train PMO: 4. TRAIN_5.bmp
# train PMO: 5. TRAIN_6.bmp
# train PMO: 6. TRAIN_7.bmp
# train PMO: 7. TRAIN_8.bmp
# train PMO: 8. TRAIN_9.bmp
# train PMO: 9. TRAIN_10.bmp
# train PMO: 10. TRAIN_11.bmp
# train PMO: 11. TRAIN_12.bmp
# train PMO: 12. TRAIN_13.bmp
# train PMO: 13. TRAIN_14.bmp
# train PMO: 14. TRAIN_15.bmp
# train PMO: 15. TRAIN_16.bmp
# train PMO: 16. TRAIN_17.bmp
# train PMO: 17. TRAIN_18.bmp
# train PMO: 18. TRAIN_19.bmp
# train PMO: 19. TRAIN_20.bmp
# train PMO: 20. TRAIN_21.bmp
# train PMO: 21. TRAIN_22.bmp
# train PMO: 22. TRAIN_23.bmp
# train PMO: 23. TRAIN_24.bmp
# train PMO: 24. TRAIN_25.bmp
# train PMO: 25. TRAIN_26.bmp
# train PMO: 26. TRAIN_27.bmp
# train PMO: 27. TRAIN_28.bmp
# train PMO: 28. TRAIN_29.bmp
# train PMO: 29. TRAIN_30.bmp
# train PMO: 30. TRAIN_31.bmp
# train PMO: 31. TRAIN_32.bmp
# train PMO: 32. TRAIN_33.bmp
# train PMO: 33. TRAIN_34.bmp
# train PMO: 34. TRAIN_35.bmp
# train PMO: 35. TRAIN_36.bmp
# train PMO: 36. TRAIN_37.bmp
# train PMO: 37. TRAIN_38.bmp
# train PMO: 38. TRAIN_39.bmp
# train PMO: 39. TRAIN_40.bmp
# train PMO: 40. TRAIN_41.bmp
# train PMO: 41. TRAIN_42.bmp
# train PMO: 42. TRAIN_43.bmp
# train PMO: 43. TRAIN_44.bmp
# train PMO: 44. TRAIN_45.bmp
# train PMO: 45. TRAIN_46.bmp
# train PMO: 46. TRAIN_47.bmp
# train PMO: 47. TRAIN_48.bmp
# train PMO: 48. TRAIN_49.bmp
# train PMO: 49. TRAIN_50.bmp
# train PMO: 50. TRAIN_51.bmp
# train PMO: 51. TRAIN_52.bmp
# train PMO: 52. TRAIN_53.bmp
# train PMO: 53. TRAIN_54.bmp
# train PMO: 54. TRAIN_55.bmp
# train PMO: 55. TRAIN_56.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/validation/PMO
# 7
# validation PMO: 0. VAL_1.bmp
# validation PMO: 1. VAL_2.bmp
# validation PMO: 2. VAL_3.bmp
# validation PMO: 3. VAL_4.bmp
# validation PMO: 4. VAL_5.bmp
# validation PMO: 5. VAL_6.bmp
# validation PMO: 6. VAL_7.bmp
# /content/drive/MyDrive/MASTER/TFM/Dataset leucemia/DatasetReducidoSplit/test/PMO
# 7
# test PMO: 0. TEST_1.bmp
# test PMO: 1. TEST_2.bmp
# test PMO: 2. TEST_3.bmp
# test PMO: 3. TEST_4.bmp
# test PMO: 4. TEST_5.bmp
# test PMO: 5. TEST_6.bmp
# test PMO: 6. TEST_7.bmp

# %% [markdown]
# ### Dataset Adaptation

# %%
train_images = np.array(train_images)
train_images = train_images.astype("float32") / 255.0
train_labels = np.array(train_labels)
val_images = np.array(val_images)
val_images = val_images.astype("float32") / 255.0
val_labels = np.array(val_labels)
test_images = np.array(test_images)
test_images = test_images.astype("float32") / 255.0
test_labels = np.array(test_labels)

# %%
batch_size = 128

# %% [markdown]
# ### Prepare datasets

# %%
indices = np.random.permutation(len(train_images))
train_images = train_images[indices]
train_labels = train_labels[indices]

indices = np.random.permutation(len(val_images))
val_images = train_images[indices]
val_labels = train_labels[indices]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
train_dataset = train_dataset.shuffle(15 * batch_size).batch(batch_size, drop_remainder=True).prefetch(buffer_size=tf.data.AUTOTUNE)
val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_labels))
val_dataset = val_dataset.shuffle(15 * batch_size).batch(batch_size, drop_remainder=True).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
print(train_dataset)
# print(birds_train_dataset)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(128, 144, 144, 3), dtype=tf.float32, name=None), TensorSpec(shape=(128, 15), dtype=tf.float32, name=None))>

# %%
plt.imshow(train_images[0])

# %% [markdown]
# # Code adaptation

# %% [markdown]
# Title: Data-efficient GANs with Adaptive Discriminator Augmentation
# Author: [András Béres](https://www.linkedin.com/in/andras-beres-789190210)
# Date created: 2021/10/28
# Last modified: 2021/10/28
# Description: Generating images from limited data using the Caltech Birds dataset.
# Accelerator: GPU
#
#
# ## Introduction
#
# ### GANs
#
# [Generative Adversarial Networks (GANs)](https://arxiv.org/abs/1406.2661) are a popular
# class of generative deep learning models, commonly used for image generation. They
# consist of a pair of dueling neural networks, called the discriminator and the generator.
# The discriminator's task is to distinguish real images from generated (fake) ones, while
# the generator network tries to fool the discriminator by generating more and more
# realistic images. If the generator is however too easy or too hard to fool, it might fail
# to provide useful learning signal for the generator, therefore training GANs is usually
# considered a difficult task.
#
# ### Data augmentation for GANS
#
# Data augmentation, a popular technique in deep learning, is the process of randomly
# applying semantics-preserving transformations to the input data to generate multiple
# realistic versions of it, thereby effectively multiplying the amount of training data
# available. The simplest example is left-right flipping an image, which preserves its
# contents while generating a second unique training sample. Data augmentation is commonly
# used in supervised learning to prevent overfitting and enhance generalization.
#
# The authors of [StyleGAN2-ADA](https://arxiv.org/abs/2006.06676) show that discriminator
# overfitting can be an issue in GANs, especially when only low amounts of training data is
# available. They propose Adaptive Discriminator Augmentation to mitigate this issue.
#
# Applying data augmentation to GANs however is not straightforward. Since the generator is
# updated using the discriminator's gradients, if the generated images are augmented, the
# augmentation pipeline has to be differentiable and also has to be GPU-compatible for
# computational efficiency. Luckily, the
# [Keras image augmentation layers](https://keras.io/api/layers/preprocessing_layers/image_augmentation/)
# fulfill both these requirements, and are therefore very well suited for this task.
#
# ### Invertible data augmentation
#
# A possible difficulty when using data augmentation in generative models is the issue of
# ["leaky augmentations" (section 2.2)](https://arxiv.org/abs/2006.06676), namely when the
# model generates images that are already augmented. This would mean that it was not able
# to separate the augmentation from the underlying data distribution, which can be caused
# by using non-invertible data transformations. For example, if either 0, 90, 180 or 270
# degree rotations are performed with equal probability, the original orientation of the
# images is impossible to infer, and this information is destroyed.
#
# A simple trick to make data augmentations invertible is to only apply them with some
# probability. That way the original version of the images will be more common, and the
# data distribution can be infered. By properly choosing this probability, one can
# effectively regularize the discriminator without making the augmentations leaky.

# %%
## Setup


import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## Hyperparameterers

# %%
# data
num_epochs = 1000  # train for 400 epochs for good results
image_size = 144
# resolution of Kernel Inception Distance measurement, see related section
kid_image_size = 75
padding = 0.25
dataset_name = "caltech_birds2011"
num_channels = 3

# adaptive discriminator augmentation
max_translation = 0.125
max_rotation = 0.125
max_zoom = 0.25
target_accuracy = 0.85
integration_steps = 1000

# architecture
noise_size = 64
depth = 4
# width is latent_dim
width = 128
leaky_relu_slope = 0.2
dropout_rate = 0.4

# optimization
batch_size = 128
learning_rate = 2e-4
beta_1 = 0.5  # not using the default value of 0.9 is important
ema = 0.99

# %%
def round_to_int(float_value):
    return tf.cast(tf.math.round(float_value), dtype=tf.int32)


def preprocess_image(data):
    # unnormalize bounding box coordinates
    height = tf.cast(tf.shape(data["image"])[0], dtype=tf.float32)
    width = tf.cast(tf.shape(data["image"])[1], dtype=tf.float32)
    bounding_box = data["bbox"] * tf.stack([height, width, height, width])

    # calculate center and length of longer side, add padding
    target_center_y = 0.5 * (bounding_box[0] + bounding_box[2])
    target_center_x = 0.5 * (bounding_box[1] + bounding_box[3])
    target_size = tf.maximum(
        (1.0 + padding) * (bounding_box[2] - bounding_box[0]),
        (1.0 + padding) * (bounding_box[3] - bounding_box[1]),
    )

    # modify crop size to fit into image
    target_height = tf.reduce_min(
        [target_size, 2.0 * target_center_y, 2.0 * (height - target_center_y)]
    )
    target_width = tf.reduce_min(
        [target_size, 2.0 * target_center_x, 2.0 * (width - target_center_x)]
    )

    # crop image
    image = tf.image.crop_to_bounding_box(
        data["image"],
        offset_height=round_to_int(target_center_y - 0.5 * target_height),
        offset_width=round_to_int(target_center_x - 0.5 * target_width),
        target_height=round_to_int(target_height),
        target_width=round_to_int(target_width),
    )

    # resize and clip
    # for image downsampling, area interpolation is the preferred method
    image = tf.image.resize(
        image, size=[image_size, image_size], method=tf.image.ResizeMethod.AREA
    )
    return tf.clip_by_value(image / 255.0, 0.0, 1.0)


def prepare_dataset(split):
    # the validation dataset is shuffled as well, because data order matters
    # for the KID calculation
    return (
        tfds.load(dataset_name, split=split, shuffle_files=True)
        .map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
        .cache()
        .shuffle(10 * batch_size)
        .batch(batch_size, drop_remainder=True)
        .prefetch(buffer_size=tf.data.AUTOTUNE)
    )


# birds_train_dataset = prepare_dataset("train")
# birds_val_dataset = prepare_dataset("test")

# %%
print(train_dataset)
# print(birds_train_dataset)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(128, 144, 144, 3), dtype=tf.float32, name=None), TensorSpec(shape=(128, 15), dtype=tf.float32, name=None))>

# %%
print(len(train_dataset.as_numpy_iterator().next()[0]))
# print(len(birds_train_dataset.as_numpy_iterator().next()))
# Out:
# 128

# %% [markdown]
# ## Data pipeline
#
# In this example, we will use the
# [Caltech Birds (2011)](https://www.tensorflow.org/datasets/catalog/caltech_birds2011) dataset for
# generating images of birds, which is a diverse natural dataset containing less then 6000
# images for training. When working with such low amounts of data, one has to take extra
# care to retain as high data quality as possible. In this example, we use the provided
# bounding boxes of the birds to cut them out with square crops while preserving their
# aspect ratios when possible.

# %% [markdown]
# After preprocessing the training images look like the following:
# ![birds dataset](https://i.imgur.com/Ru5HgBM.png)
#
#
#
# ## Kernel inception distance
#
# [Kernel Inception Distance (KID)](https://arxiv.org/abs/1801.01401) was proposed as a
# replacement for the popular
# [Frechet Inception Distance (FID)](https://arxiv.org/abs/1706.08500)
# metric for measuring image generation quality.
# Both metrics measure the difference in the generated and training distributions in the
# representation space of an [InceptionV3](https://keras.io/api/applications/inceptionv3/)
# network pretrained on
# [ImageNet](https://www.tensorflow.org/datasets/catalog/imagenet2012).
#
# According to the paper, KID was proposed because FID has no unbiased estimator, its
# expected value is higher when it is measured on fewer images. KID is more suitable for
# small datasets because its expected value does not depend on the number of samples it is
# measured on. In my experience it is also computationally lighter, numerically more
# stable, and simpler to implement because it can be estimated in a per-batch manner.
#
# In this example, the images are evaluated at the minimal possible resolution of the
# Inception network (75x75 instead of 299x299), and the metric is only measured on the
# validation set for computational efficiency.

# %%
class KID(keras.metrics.Metric):
    def __init__(self, name="kid", **kwargs):
        super().__init__(name=name, **kwargs)

        # KID is estimated per batch and is averaged across batches
        self.kid_tracker = keras.metrics.Mean()

        # a pretrained InceptionV3 is used without its classification layer
        # transform the pixel values to the 0-255 range, then use the same
        # preprocessing as during pretraining
        self.encoder = keras.Sequential(
            [
                layers.InputLayer(input_shape=(image_size, image_size, 3)),
                layers.Rescaling(255.0),
                layers.Resizing(height=kid_image_size, width=kid_image_size),
                layers.Lambda(keras.applications.inception_v3.preprocess_input),
                keras.applications.InceptionV3(
                    include_top=False,
                    input_shape=(kid_image_size, kid_image_size, 3),
                    weights="imagenet",
                ),
                layers.GlobalAveragePooling2D(),
            ],
            name="inception_encoder",
        )

    def polynomial_kernel(self, features_1, features_2):
        feature_dimensions = tf.cast(tf.shape(features_1)[1], dtype=tf.float32)
        return (features_1 @ tf.transpose(features_2) / feature_dimensions + 1.0) ** 3.0

    def update_state(self, real_images, generated_images, sample_weight=None):
        real_features = self.encoder(real_images, training=False)
        generated_features = self.encoder(generated_images, training=False)

        # compute polynomial kernels using the two sets of features
        kernel_real = self.polynomial_kernel(real_features, real_features)
        kernel_generated = self.polynomial_kernel(
            generated_features, generated_features
        )
        kernel_cross = self.polynomial_kernel(real_features, generated_features)

        # estimate the squared maximum mean discrepancy using the average kernel values
        batch_size = tf.shape(real_features)[0]
        batch_size_f = tf.cast(batch_size, dtype=tf.float32)
        mean_kernel_real = tf.reduce_sum(kernel_real * (1.0 - tf.eye(batch_size))) / (
            batch_size_f * (batch_size_f - 1.0)
        )
        mean_kernel_generated = tf.reduce_sum(
            kernel_generated * (1.0 - tf.eye(batch_size))
        ) / (batch_size_f * (batch_size_f - 1.0))
        mean_kernel_cross = tf.reduce_mean(kernel_cross)
        kid = mean_kernel_real + mean_kernel_generated - 2.0 * mean_kernel_cross

        # update the average KID estimate
        self.kid_tracker.update_state(kid)

    def result(self):
        return self.kid_tracker.result()

    def reset_state(self):
        self.kid_tracker.reset_state()

# %% [markdown]
# ## Adaptive discriminator augmentation
#
# The authors of [StyleGAN2-ADA](https://arxiv.org/abs/2006.06676) propose to change the
# augmentation probability adaptively during training. Though it is explained differently
# in the paper, they use [integral control](https://en.wikipedia.org/wiki/PID_controller#Integral) on the augmentation
# probability to keep the discriminator's accuracy on real images close to a target value.
# Note, that their controlled variable is actually the average sign of the discriminator
# logits (r_t in the paper), which corresponds to 2 * accuracy - 1.
#
# This method requires two hyperparameters:
#
# 1. `target_accuracy`: the target value for the discriminator's accuracy on real images. I
# recommend selecting its value from the 80-90% range.
# 2. [`integration_steps`](https://en.wikipedia.org/wiki/PID_controller#Mathematical_form):
# the number of update steps required for an accuracy error of 100% to transform into an
# augmentation probability increase of 100%. To give an intuition, this defines how slowly
# the augmentation probability is changed. I recommend setting this to a relatively high
# value (1000 in this case) so that the augmentation strength is only adjusted slowly.
#
# The main motivation for this procedure is that the optimal value of the target accuracy
# is similar across different dataset sizes (see [figure 4 and 5 in the paper](https://arxiv.org/abs/2006.06676)),
# so it does not have to be retuned, because the
# process automatically applies stronger data augmentation when it is needed.

# %%
# "hard sigmoid", useful for binary accuracy calculation from logits
def step(values):
    # negative values -> 0.0, positive values -> 1.0
    return 0.5 * (1.0 + tf.sign(values))


# augments images with a probability that is dynamically updated during training
class AdaptiveAugmenter(keras.Model):
    def __init__(self):
        super().__init__()

        # stores the current probability of an image being augmented
        self.probability = tf.Variable(0.0)

        # the corresponding augmentation names from the paper are shown above each layer
        # the authors show (see figure 4), that the blitting and geometric augmentations
        # are the most helpful in the low-data regime
        self.augmenter = keras.Sequential(
            [
                layers.InputLayer(input_shape=(image_size, image_size, 3)),
                # blitting/x-flip:
                layers.RandomFlip("horizontal"),
                # blitting/integer translation:
                layers.RandomTranslation(
                    height_factor=max_translation,
                    width_factor=max_translation,
                    interpolation="nearest",
                ),
                # geometric/rotation:
                layers.RandomRotation(factor=max_rotation),
                # geometric/isotropic and anisotropic scaling:
                layers.RandomZoom(
                    height_factor=(-max_zoom, 0.0), width_factor=(-max_zoom, 0.0)
                ),
            ],
            name="adaptive_augmenter",
        )

    def call(self, images, training):
        if training:
            augmented_images = self.augmenter(images, training)

            # during training either the original or the augmented images are selected
            # based on self.probability
            augmentation_values = tf.random.uniform(
                shape=(batch_size, 1, 1, 1), minval=0.0, maxval=1.0
            )
            augmentation_bools = tf.math.less(augmentation_values, self.probability)

            images = tf.where(augmentation_bools, augmented_images, images)
        return images

    def update(self, real_logits):
        current_accuracy = tf.reduce_mean(step(real_logits))

        # the augmentation probability is updated based on the dicriminator's
        # accuracy on real images
        accuracy_error = current_accuracy - target_accuracy
        self.probability.assign(
            tf.clip_by_value(
                self.probability + accuracy_error / integration_steps, 0.0, 1.0
            )
        )

# %% [markdown]
# ## Network architecture
#
# Here we specify the architecture of the two networks:
#
# * generator: maps a random vector to an image, which should be as realistic as possible
# * discriminator: maps an image to a scalar score, which should be high for real and low
# for generated images
#
# GANs tend to be sensitive to the network architecture, I implemented a DCGAN architecture
# in this example, because it is relatively stable during training while being simple to
# implement. We use a constant number of filters throughout the network, use a sigmoid
# instead of tanh in the last layer of the generator, and use default initialization
# instead of random normal as further simplifications.
#
# As a good practice, we disable the learnable scale parameter in the batch normalization
# layers, because on one hand the following relu + convolutional layers make it redundant
# (as noted in the
# [documentation](https://keras.io/api/layers/normalization_layers/batch_normalization/)).
# But also because it should be disabled based on theory when using [spectral normalization
# (section 4.1)](https://arxiv.org/abs/1802.05957), which is not used here, but is common
# in GANs. We also disable the bias in the fully connected and convolutional layers, because
# the following batch normalization makes it redundant.

# %%
generator_in_channels = noise_size + num_classes
discriminator_in_channels = num_channels + num_classes
print(generator_in_channels, discriminator_in_channels)
# Out:
# 79 18

# %%
# DCGAN generator
def get_generator():
    noise_input = keras.Input(shape=(generator_in_channels,))
    # Changed from 4 * 4 * width to 9 * 9 * width to fit the 144x144 image output
    x = layers.Dense(9 * 9 * generator_in_channels, use_bias=False)(noise_input)
    x = layers.BatchNormalization(scale=False)(x)
    x = layers.ReLU()(x)
    x = layers.Reshape(target_shape=(9, 9, generator_in_channels))(x)
    for _ in range(depth - 1):
        x = layers.Conv2DTranspose(
            width,
            kernel_size=4,
            strides=2,
            padding="same",
            use_bias=False,
        )(x)
        x = layers.BatchNormalization(scale=False)(x)
        x = layers.ReLU()(x)
    image_output = layers.Conv2DTranspose(
        3,
        kernel_size=4,
        strides=2,
        padding="same",
        activation="sigmoid",
    )(x)

    return keras.Model(noise_input, image_output, name="generator")


# DCGAN discriminator
def get_discriminator():
    image_input = keras.Input(shape=(image_size, image_size, discriminator_in_channels))
    x = image_input
    for _ in range(depth):
        x = layers.Conv2D(
            width,
            kernel_size=4,
            strides=2,
            padding="same",
            use_bias=False,
        )(x)
        x = layers.BatchNormalization(scale=False)(x)
        x = layers.LeakyReLU(alpha=leaky_relu_slope)(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(dropout_rate)(x)
    output_score = layers.Dense(1)(x)
    return keras.Model(image_input, output_score, name="discriminator")

# %% [markdown]
# ## GAN model

# %%
class GAN_ADA(keras.Model):
    def __init__(self):
        super().__init__()

        self.augmenter = AdaptiveAugmenter()
        self.generator = get_generator()
        self.ema_generator = keras.models.clone_model(self.generator)
        self.discriminator = get_discriminator()

        self.generator.summary()
        self.discriminator.summary()

    # # ---------------------------------------------------------------------------------------------------------
    # def get_config(self):
    #     config = super().get_config()
    #     return config
    # def call(self, inputs):
    #     # Define the forward pass of the model
    #     # Perform any necessary computations and return the output
    #     # Make sure to invoke the forward pass using `self.__call__(inputs)` instead of `self.call(inputs)`
    #     return self.__call__(inputs)
    # # ---------------------------------------------------------------------------------------------------------

    def compile(self, generator_optimizer, discriminator_optimizer, **kwargs):
        super().compile(**kwargs)

        # separate optimizers for the two networks
        self.generator_optimizer = generator_optimizer
        self.discriminator_optimizer = discriminator_optimizer

        self.generator_loss_tracker = keras.metrics.Mean(name="g_loss")
        self.discriminator_loss_tracker = keras.metrics.Mean(name="d_loss")
        self.real_accuracy = keras.metrics.BinaryAccuracy(name="real_acc")
        self.generated_accuracy = keras.metrics.BinaryAccuracy(name="gen_acc")
        self.augmentation_probability_tracker = keras.metrics.Mean(name="aug_p")
        self.kid = KID()

    @property
    def metrics(self):
        return [
            self.generator_loss_tracker,
            self.discriminator_loss_tracker,
            self.real_accuracy,
            self.generated_accuracy,
            self.augmentation_probability_tracker,
            self.kid,
        ]

    def generate(self, batch_size, one_hot_labels, training):

        # Sample random points in the latent space and concatenate the labels.
        # This is for the generator.
        random_latent_vectors = tf.random.normal(shape=(batch_size, noise_size))
        random_vector_labels = tf.concat(
            [random_latent_vectors, one_hot_labels], axis=1
        )

        # use ema_generator during inference
        if training:
            generated_images = self.generator(random_vector_labels, training)
        else:
            generated_images = self.ema_generator(random_vector_labels, training)
        return generated_images

    def adversarial_loss(self, real_logits, generated_logits):
        # this is usually called the non-saturating GAN loss

        real_labels = tf.ones(shape=(batch_size, 1))
        generated_labels = tf.zeros(shape=(batch_size, 1))

        # the generator tries to produce images that the discriminator considers as real
        generator_loss = keras.losses.binary_crossentropy(
            real_labels, generated_logits, from_logits=True
        )
        # the discriminator tries to determine if images are real or generated
        discriminator_loss = keras.losses.binary_crossentropy(
            tf.concat([real_labels, generated_labels], axis=0),
            tf.concat([real_logits, generated_logits], axis=0),
            from_logits=True,
        )

        return tf.reduce_mean(generator_loss), tf.reduce_mean(discriminator_loss)

    def train_step(self, data):
        real_images, one_hot_labels = data
        print(f"data: {data}\nreal_images: {real_images}\none_hot_labels: {one_hot_labels}")
        real_images = self.augmenter(real_images, training=True)

        # Add dummy dimensions to the labels so that they can be concatenated with
        # the images. This is for the discriminator.
        image_one_hot_labels = one_hot_labels[:, :, None, None]
        image_one_hot_labels = tf.repeat(
            image_one_hot_labels, repeats=[image_size * image_size]
        )
        image_one_hot_labels = tf.reshape(
            image_one_hot_labels, (-1, image_size, image_size, num_classes)
        )

        # use persistent gradient tape because gradients will be calculated twice
        with tf.GradientTape(persistent=True) as tape:
            generated_images = self.generate(batch_size, one_hot_labels, training=True)
            # gradient is calculated through the image augmentation
            generated_images = self.augmenter(generated_images, training=True)

            # Combine them with real images. Note that we are concatenating the labels
            # with these images here.
            fake_image_and_labels = tf.concat([generated_images, image_one_hot_labels], -1)
            real_image_and_labels = tf.concat([real_images, image_one_hot_labels], -1)
            combined_images = tf.concat(
                [fake_image_and_labels, real_image_and_labels], axis=0
            )

            # separate forward passes for the real and generated images, meaning
            # that batch normalization is applied separately
            real_logits = self.discriminator(real_image_and_labels, training=True)
            generated_logits = self.discriminator(fake_image_and_labels, training=True)

            generator_loss, discriminator_loss = self.adversarial_loss(
                real_logits, generated_logits
            )

        # calculate gradients and update weights
        generator_gradients = tape.gradient(
            generator_loss, self.generator.trainable_weights
        )
        discriminator_gradients = tape.gradient(
            discriminator_loss, self.discriminator.trainable_weights
        )
        self.generator_optimizer.apply_gradients(
            zip(generator_gradients, self.generator.trainable_weights)
        )
        self.discriminator_optimizer.apply_gradients(
            zip(discriminator_gradients, self.discriminator.trainable_weights)
        )

        # update the augmentation probability based on the discriminator's performance
        self.augmenter.update(real_logits)

        self.generator_loss_tracker.update_state(generator_loss)
        self.discriminator_loss_tracker.update_state(discriminator_loss)
        self.real_accuracy.update_state(1.0, step(real_logits))
        self.generated_accuracy.update_state(0.0, step(generated_logits))
        self.augmentation_probability_tracker.update_state(self.augmenter.probability)

        # track the exponential moving average of the generator's weights to decrease
        # variance in the generation quality
        for weight, ema_weight in zip(
            self.generator.weights, self.ema_generator.weights
        ):
            ema_weight.assign(ema * ema_weight + (1 - ema) * weight)

        # KID is not measured during the training phase for computational efficiency
        return {m.name: m.result() for m in self.metrics[:-1]}



    def test_step(self, data):
        real_images, one_hot_labels = data
        generated_images = self.generate(batch_size, one_hot_labels, training=False)

        self.kid.update_state(real_images, generated_images)

        # only KID is measured during the evaluation phase for computational efficiency
        return {self.kid.name: self.kid.result()}

    def plot_images(self, epoch=None, logs=None, num_rows=4, num_cols=4, interval=5):
        # plot random generated images for visual evaluation of generation quality
        if epoch is None or (epoch + 1) % interval == 0:
            num_images = num_classes
            # random_labels = [random.randint(0, num_classes-1) for _ in range(num_images)]
            labels = [l for l in range(num_classes)]
            one_hot_labels = [to_categorical(label, num_classes) for label in labels]

            generated_images = self.generate(num_images, one_hot_labels, training=False)

            plt.figure(figsize=(num_cols * 2.0, num_rows * 2.0))
            for row in range(num_rows):
                for col in range(num_cols):
                    index = row * num_cols + col
                    if (index >= num_classes): break
                    plt.subplot(num_rows, num_cols, index + 1)
                    plt.imshow(generated_images[index])
                    label_code = labels[index]
                    plt.text(0, -10, f"{CODE_TO_LABEL[label_code]} [{label_code}]", ha='center')
                    plt.axis("off")
            plt.tight_layout()
            plt.show()
            plt.close()

# %% [markdown]
# ## Training
#
# One can should see from the metrics during training, that if the real accuracy
# (discriminator's accuracy on real images) is below the target accuracy, the augmentation
# probability is increased, and vice versa. In my experience, during a healthy GAN
# training, the discriminator accuracy should stay in the 80-95% range. Below that, the
# discriminator is too weak, above that it is too strong.
#
# Note that we track the exponential moving average of the generator's weights, and use that
# for image generation and KID evaluation.

# %%
# create and compile the model
model = GAN_ADA()
model.compile(
    generator_optimizer=keras.optimizers.Adam(learning_rate, beta_1),
    discriminator_optimizer=keras.optimizers.Adam(learning_rate, beta_1),
)

# # save the best model based on the validation KID metric
checkpoint_path = os.path.join(ADA_MODEL_PATH,"gan_model")
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_kid",
    mode="min",
    save_best_only=True,
)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 79)]              0
#
#  dense (Dense)               (None, 6399)              505521
#
#  batch_normalization (BatchN  (None, 6399)             19197
#  ormalization)
#
#  re_lu (ReLU)                (None, 6399)              0
#
#  reshape (Reshape)           (None, 9, 9, 79)          0
#
#  conv2d_transpose (Conv2DTra  (None, 18, 18, 128)      161792
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 18, 18, 128)      384
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 18, 18, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 36, 36, 128)      262144
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 36, 36, 128)      384
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 36, 36, 128)       0
#
#  conv2d_transpose_2 (Conv2DT  (None, 72, 72, 128)      262144
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 72, 72, 128)      384
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 72, 72, 128)       0
#
#  conv2d_transpose_3 (Conv2DT  (None, 144, 144, 3)      6147
#  ranspose)
#
# =================================================================
# Total params: 1,218,097
# Trainable params: 1,204,531
# Non-trainable params: 13,566
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 144, 144, 18)]    0
#
#  conv2d (Conv2D)             (None, 72, 72, 128)       36864
#
#  batch_normalization_4 (Batc  (None, 72, 72, 128)      384
#  hNormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 72, 72, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 36, 36, 128)       262144
#
#  batch_normalization_5 (Batc  (None, 36, 36, 128)      384
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 36, 36, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 18, 18, 128)       262144
#
#  batch_normalization_6 (Batc  (None, 18, 18, 128)      384
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 18, 18, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 9, 9, 128)         262144
#
#  batch_normalization_7 (Batc  (None, 9, 9, 128)        384
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 9, 9, 128)         0
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dropout (Dropout)           (None, 10368)             0
#
#  dense_1 (Dense)             (None, 1)                 10369
#
# =================================================================
# Total params: 835,201
# Trainable params: 834,177
# Non-trainable params: 1,024
# _________________________________________________________________
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
# run training and plot generated images periodically

r = model.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=val_dataset,
    callbacks=[
        keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images),
        checkpoint_callback,
    ],
)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Inference

# %%
# load the best model and generate images
model.load_weights(checkpoint_path)
model.plot_images()

# %%
if(not os.path.exists(ADA_TRAIN_DATA_PATH)): os.mkdir(ADA_TRAIN_DATA_PATH)

r_name = 'history.pickle'
r_save_path = os.path.join(ADA_TRAIN_DATA_PATH, r_name)

# %%
with open(r_save_path, 'rb') as f:
    model_history = pickle.load(f)

# %%
# Get the metrics from the model history
metrics = list(model_history.keys())

# Plot each metric
for metric in metrics:
    # Get the metric values
    values = model_history[metric]

    # Create the plot
    plt.plot(values)
    plt.xlabel('Epoch')
    plt.ylabel(metric)
    plt.title(f'{metric} vs Epoch')
    plt.show()

# %%
with open(r_save_path, 'wb') as handle:
    pickle.dump(r.history, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Delete the runtime at the end of the execution
if(DELETE_RUNTIME_AT_END): runtime.unassign()

# %% [markdown]
# ## Results
#
# By running the training for 400 epochs (which takes 2-3 hours in a Colab notebook), one
# can get high quality image generations using this code example.
#
# The evolution of a random batch of images over a 400 epoch training (ema=0.999 for
# animation smoothness):
# ![birds evolution gif](https://i.imgur.com/ecGuCcz.gif)
#
# Latent-space interpolation between a batch of selected images:
# ![birds interpolation gif](https://i.imgur.com/nGvzlsC.gif)
#
# I also recommend trying out training on other datasets, such as
# [CelebA](https://www.tensorflow.org/datasets/catalog/celeb_a) for example. In my
# experience good results can be achieved without changing any hyperparameters (though
# discriminator augmentation might not be necessary).
#
# ## GAN tips and tricks
#
# My goal with this example was to find a good tradeoff between ease of implementation and
# generation quality for GANs. During preparation I have run numerous ablations using
# [this repository](https://github.com/beresandras/gan-flavours-keras).
#
# In this section I list the lessons learned and my recommendations in my subjective order
# of importance.
#
# I recommend checking out the [DCGAN paper](https://arxiv.org/abs/1511.06434), this
# [NeurIPS talk](https://www.youtube.com/watch?v=myGAju4L7O8), and this
# [large scale GAN study](https://arxiv.org/abs/1711.10337) for others' takes on this subject.
#
# ### Architectural tips
#
# * **resolution**: Training GANs at higher resolutions tends to get more difficult, I
# recommend experimenting at 32x32 or 64x64 resolutions initially.
# * **initialization**: If you see strong colorful patterns early on in the training, the
# initalization might be the issue. Set the kernel_initializer parameters of layers to
# [random normal](https://keras.io/api/layers/initializers/#randomnormal-class), and
# decrease the standard deviation (recommended value: 0.02, following DCGAN) until the
# issue disappears.
# * **upsampling**: There are two main methods for upsampling in the generator.
# [Transposed convolution](https://keras.io/api/layers/convolution_layers/convolution2d_transpose/)
# is faster, but can lead to
# [checkerboard artifacts](https://distill.pub/2016/deconv-checkerboard/), which can be reduced by using
# a kernel size that is divisible with the stride (recommended kernel size is 4 for a stride of 2).
# [Upsampling](https://keras.io/api/layers/reshaping_layers/up_sampling2d/) +
# [standard convolution](https://keras.io/api/layers/convolution_layers/convolution2d/) can have slightly
# lower quality, but checkerboard artifacts are not an issue. I recommend using nearest-neighbor
# interpolation over bilinear for it.
# * **batch normalization in discriminator**: Sometimes has a high impact, I recommend
# trying out both ways.
# * **[spectral normalization](https://www.tensorflow.org/addons/api_docs/python/tfa/layers/SpectralNormalization)**:
# A popular technique for training GANs, can help with stability. I recommend
# disabling batch normalization's learnable scale parameters along with it.
# * **[residual connections](https://keras.io/guides/functional_api/#a-toy-resnet-model)**:
# While residual discriminators behave similarly, residual generators are more difficult to
# train in my experience. They are however necessary for training large and deep
# architectures. I recommend starting with non-resiudal architectures.
# * **dropout**: Using dropout before the last layer of the discriminator improves
# generation quality in my experience. Recommended dropout rate is below 0.5.
# * **[leaky ReLU](https://keras.io/api/layers/activation_layers/leaky_relu/)**: Use leaky
# ReLU activations in the discriminator to make its gradients less sparse. Recommended
# slope/alpha is 0.2 following DCGAN.
#
# ### Algorithmic tips
#
# * **loss functions**: Numerous losses have been proposed over the years for training
# GANs, promising improved performance and stability. I have implemented 5 of them in
# [this repository](https://github.com/beresandras/gan-flavours-keras), and my experience is in
# line with [this GAN study](https://arxiv.org/abs/1711.10337): no loss seems to
# consistently outperform the default non-saturating GAN loss. I recommend using that as a
# default.
# * **Adam's beta_1 parameter**: The beta_1 parameter in Adam can be interpreted as the
# momentum of mean gradient estimation. Using 0.5 or even 0.0 instead of the default 0.9
# value was proposed in DCGAN and is important. This example would not work using its
# default value.
# * **separate batch normalization for generated and real images**: The forward pass of the
# discriminator should be separate for the generated and real images. Doing otherwise can
# lead to artifacts (45 degree stripes in my case) and decreased performance.
# * **exponential moving average of generator's weights**: This helps to reduce the
# variance of the KID measurement, and helps in averaging out the rapid color palette
# changes during training.
# * **[different learning rate for generator and discriminator](https://arxiv.org/abs/1706.08500)**:
# If one has the resources, it can help
# to tune the learning rates of the two networks separately. A similar idea is to update
# either network's (usually the discriminator's) weights multiple times for each of the
# other network's updates. I recommend using the same learning rate of 2e-4 (Adam),
# following DCGAN for both networks, and only updating both of them once as a default.
# * **label noise**: [One-sided label smoothing](https://arxiv.org/abs/1606.03498) (using
# less than 1.0 for real labels), or adding noise to the labels can regularize the
# discriminator not to get overconfident, however in my case they did not improve
# performance.
# * **adaptive data augmentation**: Since it adds another dynamic component to the training
# process, disable it as a default, and only enable it when the other components already
# work well.
#
#
#
# ## Related works
#
# Other GAN-related Keras code examples:
#
# * [DCGAN + CelebA](https://keras.io/examples/generative/dcgan_overriding_train_step/)
# * [WGAN + FashionMNIST](https://keras.io/examples/generative/wgan_gp/)
# * [WGAN + Molecules](https://keras.io/examples/generative/wgan-graphs/)
# * [ConditionalGAN + MNIST](https://keras.io/examples/generative/conditional_gan/)
# * [CycleGAN + Horse2Zebra](https://keras.io/examples/generative/cyclegan/)
# * [StyleGAN](https://keras.io/examples/generative/stylegan/)
#
# Modern GAN architecture-lines:
#
# * [SAGAN](https://arxiv.org/abs/1805.08318), [BigGAN](https://arxiv.org/abs/1809.11096)
# * [ProgressiveGAN](https://arxiv.org/abs/1710.10196),
# [StyleGAN](https://arxiv.org/abs/1812.04948),
# [StyleGAN2](https://arxiv.org/abs/1912.04958),
# [StyleGAN2-ADA](https://arxiv.org/abs/2006.06676),
# [AliasFreeGAN](https://arxiv.org/abs/2106.12423)
#
# Concurrent papers on discriminator data augmentation:
# [1](https://arxiv.org/abs/2006.02595), [2](https://arxiv.org/abs/2006.05338), [3](https://arxiv.org/abs/2006.10738)
#
# Recent literature overview on GANs: [talk](https://www.youtube.com/watch?v=3ktD752xq5k)
